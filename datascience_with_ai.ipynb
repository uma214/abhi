# %% [markdown]
# <a href="https://colab.research.google.com/github/uma214/abhi/blob/main/datascience_with_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = 'hello world'
print(data)
# Out:
# hello world
